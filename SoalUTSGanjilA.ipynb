# %% [markdown]
# <a href="https://colab.research.google.com/github/Nurra0210/Histogram/blob/main/SoalUTSGanjilA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Code di atas memrintahkan bahwa image ya akan di edit diambil dar google drive

# %%
#link image
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread("/content/drive/MyDrive/Colab Notebooks/Tintin.jpg", cv2.IMREAD_UNCHANGED)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640 at 0x7FB2AE178390>

# %% [markdown]
# Nah dia atas adalah tamplan setelah pemanggilan image dari google drive

# %%
print(img.size)
print(img.shape)
print(img.dtype)
# Out:
# 1228800
# (640, 640, 3)
# uint8

# %% [markdown]
# untuk kod di atas yaitu mengatur ukuran image tersebut

# %%
import numpy as np
a = np.array([[1,2,2,2,10],[10,20,30,40,50]])
print(a)
print(a.ravel())
print(a.flatten())
plt.hist(a.ravel(),bins=50, range=[0,50])
plt.show()
# Out:
# [[ 1  2  2  2 10]
#  [10 20 30 40 50]]
# [ 1  2  2  2 10 10 20 30 40 50]
# [ 1  2  2  2 10 10 20 30 40 50]

# %% [markdown]
# untuk kode di atas unyuk mengatur editan untuk image tersebutb diatas menggunakan histogram

# %%
plt.hist(img.ravel(), bins = 256, range = [0,256])
plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv.calcHist([img], [i], None, [256], [0,256])
  plt.plot(histogr, color = col)
  plt.xlim([0,256])
plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv.calcHist([img], [i], None, [4], [0,256])
  plt.plot(histogr, color = col)
plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv.calcHist([img], [i], None, [8], [0,256])
  plt.plot(histogr, color = col)
  plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv2.calcHist([img], [i], None, [16], [0,256])
  plt.plot(histogr, color = col)
plt.show()

# %%
color = ('b','g','r')
for i,col in enumerate(color):
  histogr = cv2.calcHist([img], [i], None, [32], [0,256])
  plt.plot(histogr, color = col)
plt.show()

# %%
b,g,r = cv.split(img)
cv2_imshow(b)
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x7FB2ABB6A210>

# %%
#blue channel
bluech = img[:,:,0]
cv2_imshow(bluech)
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x7FB2ABA0AED0>

# %%
plt.hist(bluech.ravel(), 16, [0, 256], color='blue')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 8, [0, 256], color='blue')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 32, [0, 256], color='blue')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 256, [0, 256], color='blue')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 4, [0, 256], color='blue')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
plt.show()

# %%
#green channel
greench = img[:,:,1]
cv2_imshow(greench)
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x7FB2AADCEED0>

# %%
plt.hist(bluech.ravel(), 8, [0, 256], color='green')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 4, [0, 256], color='green')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 16, [0, 256], color='green')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 32, [0, 256], color='green')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(bluech.ravel(), 256, [0, 256], color='green')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %%
#red channel

redch = img[:,:,2]
cv2_imshow(redch)
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x7FB2ABB1D410>

# %%
plt.hist(redch.ravel(), 256, [0, 256], color='red')
plt.xlabel('Bins 256')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(redch.ravel(), 32, [0, 256], color='red')
plt.xlabel('Bins 8')
plt.ylabel('Num of Pixel')
plt.show()

# %%
plt.hist(redch.ravel(), 16, [0, 256], color='red')
plt.xlabel('Bins 16')
plt.ylabel('Num of Pixel')
# Out:
# Text(0, 0.5, 'Num of Pixel')

# %%
plt.hist(redch.ravel(), 8, [0, 256], color='red')
plt.xlabel('Bins 32')
plt.ylabel('Num of Pixel')
# Out:
# Text(0, 0.5, 'Num of Pixel')

# %%
plt.hist(redch.ravel(), 4, [0, 256], color='red')
plt.xlabel('Bins 4')
plt.ylabel('Num of Pixel')
# Out:
# Text(0, 0.5, 'Num of Pixel')

# %%
gray_img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
cv2_imshow(gray_img)
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x7FB2AB9A6750>

# %%
plt.hist(gray_image.ravel(), bins = 256, range = [0,256])
plt.show()


print(gray_image.size)
print(gray_image.shape)
print(gray_image.dtype)
# Out:
# 409600
# (640, 640)
# uint8

# %%
plt.hist(gray_image.ravel(), bins = 4, range = [0,256])
plt.show()


print(gray_image.size)
print(gray_image.shape)
print(gray_image.dtype)
# Out:
# 409600
# (640, 640)
# uint8

# %%
invert_gray = 255 - gray_img
cv2_imshow(invert_gray)
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x7FB2AAB64750>

# %%
plt.hist(invert_gray.ravel(), bins = 256, range = [0,256])
plt.show()

# %%
bright_image = (100.0/255)*gray_image + 100
cv2_imshow(bright_image)
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x7FB2AA7CD290>

# %%
plt.hist(bright_image.ravel(), bins = 256, range = [0,256])
plt.show()

# %%
darken_img = 255.0*(gray_img/255.0)**2
cv2_imshow(darken_img)
# Out:
# <PIL.Image.Image image mode=L size=640x640 at 0x7FB2AAB1FCD0>

# %%
plt.hist(darken_img.ravel(), bins = 256, range = [0,256])
plt.show()
